# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat459/python/blob/main/pandas_day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/placement.csv')

# %%
top_left=df.iloc[:5,:3]
top_left
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df2=df.loc[1:3]
df2
# Out:
#    cgpa  resume_score  placed
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.shape
# Out:
# (100, 3)

# %%
s=df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
p=df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b=df.empty
b
# Out:
# False

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (100, 3)

# %%
df.size
# Out:
# 300

# %%
df.values
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df.sort_values(by='resume_score')
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['resume_score'].plot(kind='hist', bins=20, title='resume_score')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['placed'].plot(kind='hist', bins=20, title='placed')
# ...

# %%
from matplotlib import pyplot as plt
_df_0['cgpa'].plot(kind='hist', bins=20, title='cgpa')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Correct way
p['cgpa'] = p['cgpa'].astype(int)
df

# %%
df['cgpa']=df['cgpa'].add(4)
df
# Out:
#      cgpa  resume_score  placed
# 0   16.14          6.52       1
# 1   14.17          5.17       0
# 2   16.27          8.86       1
# 3   14.88          7.27       1
# 4   15.52          7.30       1
# ..    ...           ...     ...
# 95  14.33          6.38       0
# 96  16.23          7.76       1
# 97  14.65          7.78       0
# 98  16.14          5.63       1
# 99  14.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['resume_score']=df['resume_score'].add(4)
df
# Out:
#      cgpa  resume_score  placed
# 0   16.14         10.52       1
# 1   14.17          9.17       0
# 2   16.27         12.86       1
# 3   14.88         11.27       1
# 4   15.52         11.30       1
# ..    ...           ...     ...
# 95  14.33         10.38       0
# 96  16.23         11.76       1
# 97  14.65         11.78       0
# 98  16.14          9.63       1
# 99  14.09         10.61       0
#
# [100 rows x 3 columns]

# %%
df['placed']=df['placed'].add(4)
df
# Out:
#      cgpa  resume_score  placed
# 0   16.14         10.52       5
# 1   14.17          9.17       4
# 2   16.27         12.86       5
# 3   14.88         11.27       5
# 4   15.52         11.30       5
# ..    ...           ...     ...
# 95  14.33         10.38       4
# 96  16.23         11.76       5
# 97  14.65         11.78       4
# 98  16.14          9.63       5
# 99  14.09         10.61       4
#
# [100 rows x 3 columns]

# %%
s=df.count
s
# Out:
# <bound method DataFrame.count of      cgpa  resume_score  placed
# 0   16.14         10.52       5
# 1   14.17          9.17       4
# 2   16.27         12.86       5
# 3   14.88         11.27       5
# 4   15.52         11.30       5
# ..    ...           ...     ...
# 95  14.33         10.38       4
# 96  16.23         11.76       5
# 97  14.65         11.78       4
# 98  16.14          9.63       5
# 99  14.09         10.61       4
#
# [100 rows x 3 columns]>

# %%
df.max
# Out:
# <bound method DataFrame.idxmax of      cgpa  resume_score  placed
# 0   16.14         10.52       5
# 1   14.17          9.17       4
# 2   16.27         12.86       5
# 3   14.88         11.27       5
# 4   15.52         11.30       5
# ..    ...           ...     ...
# 95  14.33         10.38       4
# 96  16.23         11.76       5
# 97  14.65         11.78       4
# 98  16.14          9.63       5
# 99  14.09         10.61       4
#
# [100 rows x 3 columns]>

# %%
s=df['cgpa'].median()
s
# Out:
# 14.620000000000001

# %%
r=df['cgpa'].mean()
r
# Out:
# 14.942200000000003

# %%
g=df.filter(items=['cgpa','resume_score'])
g
# Out:
#      cgpa  resume_score
# 0   16.14         10.52
# 1   14.17          9.17
# 2   16.27         12.86
# 3   14.88         11.27
# 4   15.52         11.30
# ..    ...           ...
# 95  14.33         10.38
# 96  16.23         11.76
# 97  14.65         11.78
# 98  16.14          9.63
# 99  14.09         10.61
#
# [100 rows x 2 columns]

# %%
s=df.filter(items=[3,4,5,6], axis=0)
s
# Out:
#     cgpa  resume_score  placed
# 3  14.88         11.27       5
# 4  15.52         11.30       5
# 5  16.77         10.19       5
# 6  13.34         11.09       4

# %%
p=df.rename(columns={'cgpa':'cgpa_new'})
p
# Out:
#     cgpa_new  resume_score  placed
# 0      16.14         10.52       5
# 1      14.17          9.17       4
# 2      16.27         12.86       5
# 3      14.88         11.27       5
# 4      15.52         11.30       5
# ..       ...           ...     ...
# 95     14.33         10.38       4
# 96     16.23         11.76       5
# 97     14.65         11.78       4
# 98     16.14          9.63       5
# 99     14.09         10.61       4
#
# [100 rows x 3 columns]

# %%
df
# Out:
#      cgpa  resume_score  placed
# 0   16.14         10.52       5
# 1   14.17          9.17       4
# 2   16.27         12.86       5
# 3   14.88         11.27       5
# 4   15.52         11.30       5
# ..    ...           ...     ...
# 95  14.33         10.38       4
# 96  16.23         11.76       5
# 97  14.65         11.78       4
# 98  16.14          9.63       5
# 99  14.09         10.61       4
#
# [100 rows x 3 columns]

# %%
df['half']=df['cgpa'].where(df['cgpa']>15,other=0)
df
# Out:
#      cgpa  resume_score  placed   half
# 0   16.14         10.52       5  16.14
# 1   14.17          9.17       4   0.00
# 2   16.27         12.86       5  16.27
# 3   14.88         11.27       5   0.00
# 4   15.52         11.30       5  15.52
# ..    ...           ...     ...    ...
# 95  14.33         10.38       4   0.00
# 96  16.23         11.76       5  16.23
# 97  14.65         11.78       4   0.00
# 98  16.14          9.63       5  16.14
# 99  14.09         10.61       4   0.00
#
# [100 rows x 4 columns]
