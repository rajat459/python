# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat459/python/blob/main/advance_python_panda_day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas--->it is an open source libbrary  that is used for data manipulation
#datastructure of pandas----->
#1---seies---> it is an one dimensionsal array and it contains only value not column name
#2---dataframe----it is an multi dimensional array and it contains value with column name
import pandas as pd

# %%
a=pd.Series([1,2,3,4,5])
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a={
    "emp_id":[1,2,3,4,5],
    "emp_name":["a","b","c","d","e"],
    "emp_sal" : [1000,2000,3000,4000,5000,]

}
df=pd.DataFrame(a)
print(df)
# Out:
#    emp_id emp_name  emp_sal
# 0       1        a     1000
# 1       2        b     2000
# 2       3        c     3000
# 3       4        d     4000
# 4       5        e     5000

# %%
df.to_csv("C:\\Users\\Jayant\\OneDrive\\Desktop\\rajat_info ",index=False)

# %%
df2=pd.read_csv("C:\\Users\\Jayant\\OneDrive\\Desktop\\rajat_info ")
df2
# Out:
#    emp_id emp_name  emp_sal
# 0       1        a     1000
# 1       2        b     2000
# 2       3        c     3000
# 3       4        d     4000
# 4       5        e     5000

# %%
df.to_csv("rajat_info",index=False)

# %%
df2=pd.read_csv("rajat_info")
df2
# Out:
#    emp_id emp_name  emp_sal
# 0       1        a     1000
# 1       2        b     2000
# 2       3        c     3000
# 3       4        d     4000
# 4       5        e     5000

# %%
df.head
# Out:
# <bound method NDFrame.head of    emp_id emp_name  emp_sal
# 0       1        a     1000
# 1       2        b     2000
# 2       3        c     3000
# 3       4        d     4000
# 4       5        e     5000>

# %%
df.head(2)
# Out:
#    emp_id emp_name  emp_sal
# 0       1        a     1000
# 1       2        b     2000

# %%
df.tail()
# Out:
#    emp_id emp_name  emp_sal
# 0       1        a     1000
# 1       2        b     2000
# 2       3        c     3000
# 3       4        d     4000
# 4       5        e     5000

# %%
df.tail(2)
# Out:
#    emp_id emp_name  emp_sal
# 3       4        d     4000
# 4       5        e     5000

# %%
df.sample(3)
# Out:
#    emp_id emp_name  emp_sal
# 1       2        b     2000
# 2       3        c     3000
# 0       1        a     1000

# %%
df.shape
# Out:
# (5, 3)

# %%
df.columns
# Out:
# Index(['emp_id', 'emp_name', 'emp_sal'], dtype='object')

# %%
#case1=how to update the names and time and other things
df['emp_id']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: emp_id, dtype: int64

# %%
df['emp_name']
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# Name: emp_name, dtype: object

# %%
df['emp_name'][2]='rajat'
df['emp_name'][1]='bharti'
# Out:
# <ipython-input-36-83eb0186ed05>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emp_name'][2]='rajat'
# <ipython-input-36-83eb0186ed05>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emp_name'][1]='bharti'

# %%
df
# Out:
#    emp_id emp_name  emp_sal
# 0       1        a     1000
# 1       2   bharti     2000
# 2       3    rajat     3000
# 3       4        d     4000
# 4       5        e     5000

# %%
df['emp_sal'][1]='1000000'
# Out:
# <ipython-input-40-6c70c22e5f74>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['emp_sal'][1]='1000000'
# <ipython-input-40-6c70c22e5f74>:1: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#    emp_id emp_name  emp_sal
# 0       1        a     1000
# 1       2   bharti  1000000
# 2       3    rajat     3000
# 3       4        d     4000
# 4       5        e     5000

# %%
df.isnull().sum()
# Out:
# emp_id      0
# emp_name    0
# emp_sal     0
# dtype: int64

# %%
df
# Out:
#    emp_id emp_name  emp_sal
# 0       1        a     1000
# 1       2   bharti  1000000
# 2       3    rajat     3000
# 3       4        d     4000
# 4       5        e     5000

# %%
df['emp_name'][0]=None
df['emp_name'][3]=None
# Out:
# <ipython-input-44-1db7b5766b78>:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['emp_name'][0]=None
# <ipython-input-44-1db7b5766b78>:1: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#    emp_id emp_name  emp_sal
# 0       1     None     1000
# 1       2   bharti  1000000
# 2       3    rajat     3000
# 3       4     None     4000
# 4       5        e     5000

# %%
df=df.dropna()

# %%
df
# Out:
#    emp_id emp_name  emp_sal
# 1       2   bharti  1000000
# 2       3    rajat     3000
# 4       5        e     5000
