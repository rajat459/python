# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat459/python/blob/main/pandas_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/covid_toy.csv')
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.value_counts()
# Out:
# age  gender  fever  cough   city       has_covid
# 27   Male    100.0  Mild    Delhi      Yes          2
# 5    Female  98.0   Strong  Mumbai     No           1
# 65   Male    99.0   Mild    Bangalore  No           1
#      Female  98.0   Mild    Mumbai     Yes          1
# 64   Male    102.0  Mild    Bangalore  Yes          1
#                                                    ..
# 24   Female  102.0  Strong  Bangalore  Yes          1
# 23   Male    98.0   Strong  Mumbai     Yes          1
# 22   Female  99.0   Mild    Bangalore  Yes          1
# 20   Male    102.0  Strong  Delhi      No           1
# 83   Male    103.0  Mild    Kolkata    No           1
# Name: count, Length: 89, dtype: int64

# %%
df['gender']=df['gender'].map({'Male':1,'Female':0})
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60       1  103.0  Mild  Kolkata        No
# 1   27       1  100.0  Mild    Delhi       Yes
# 2   42       1  101.0  Mild    Delhi        No
# 3   31       0   98.0  Mild  Kolkata        No
# 4   65       0  101.0  Mild   Mumbai        No

# %%
df['cough']=df['cough'].map({'Mild':1,'Strong':2})
df.head()
# Out:
#    age  gender  fever  cough     city has_covid
# 0   60       1  103.0      1  Kolkata        No
# 1   27       1  100.0      1    Delhi       Yes
# 2   42       1  101.0      1    Delhi        No
# 3   31       0   98.0      1  Kolkata        No
# 4   65       0  101.0      1   Mumbai        No

# %%
df.iloc[:5,:2]
# Out:
#    age  gender
# 0   60    Male
# 1   27    Male
# 2   42    Male
# 3   31  Female
# 4   65  Female

# %%
df.loc[2:5]
# Out:
#    age  gender  fever cough       city has_covid
# 2   42    Male  101.0  Mild      Delhi        No
# 3   31  Female   98.0  Mild    Kolkata        No
# 4   65  Female  101.0  Mild     Mumbai        No
# 5   84  Female    NaN  Mild  Bangalore       Yes

# %%
df.shape
# Out:
# (100, 6)

# %%
df.ndim
# Out:
# 2

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')]

# %%
df.dtypes
# Out:
# age            int64
# gender        object
# fever        float64
# cough         object
# city          object
# has_covid     object
# dtype: object

# %%
df.empty
# Out:
# False

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.shape
# Out:
# (100, 6)

# %%
df.size
# Out:
# 600

# %%
df.values
# Out:
# array([[60, 1, 103.0, 1, 'Kolkata', 'No'],
#        [27, 1, 100.0, 1, 'Delhi', 'Yes'],
#        [42, 1, 101.0, 1, 'Delhi', 'No'],
#        [31, 0, 98.0, 1, 'Kolkata', 'No'],
#        [65, 0, 101.0, 1, 'Mumbai', 'No'],
#        [84, 0, nan, 1, 'Bangalore', 'Yes'],
#        [14, 1, 101.0, 2, 'Bangalore', 'No'],
#        [20, 0, nan, 2, 'Mumbai', 'Yes'],
#        [19, 0, 100.0, 2, 'Bangalore', 'No'],
#        [64, 0, 101.0, 1, 'Delhi', 'No'],
#        [75, 0, nan, 1, 'Delhi', 'No'],
#        [65, 0, 98.0, 1, 'Mumbai', 'Yes'],
#        [25, 0, 99.0, 2, 'Kolkata', 'No'],
#        [64, 1, 102.0, 1, 'Bangalore', 'Yes'],
#        [51, 1, 104.0, 1, 'Bangalore', 'No'],
#        [70, 1, 103.0, 2, 'Kolkata', 'Yes'],
#        [69, 0, 103.0, 1, 'Kolkata', 'Yes'],
#        [40, 0, 98.0, 2, 'Delhi', 'No'],
#        [64, 0, 98.0, 1, 'Bangalore', 'Yes'],
#        [42, 0, nan, 2, 'Bangalore', 'Yes'],
#        [12, 1, 98.0, 2, 'Bangalore', 'No'],
#        [73, 1, 98.0, 1, 'Bangalore', 'Yes'],
# ...

# %%
df.sort_values(by='fever')
# Out:
#     age  gender  fever  cough     city has_covid
# 99   10       0   98.0      2  Kolkata       Yes
# 98    5       0   98.0      2   Mumbai        No
# 33   26       0   98.0      1  Kolkata        No
# 53   83       1   98.0      1    Delhi       Yes
# 58   23       1   98.0      2   Mumbai       Yes
# ..  ...     ...    ...    ...      ...       ...
# 29   34       0    NaN      2   Mumbai       Yes
# 41   82       1    NaN      1  Kolkata       Yes
# 56   71       1    NaN      2  Kolkata        No
# 91   38       1    NaN      1    Delhi       Yes
# 94   79       1    NaN      2  Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.sort_values(by='age')
# Out:
#     age  gender  fever  cough       city has_covid
# 98    5       0   98.0      2     Mumbai        No
# 75    5       1  102.0      1    Kolkata       Yes
# 88    5       0  100.0      1    Kolkata        No
# 59    6       0  104.0      1    Kolkata       Yes
# 77    8       0  101.0      1    Kolkata        No
# ..  ...     ...    ...    ...        ...       ...
# 35   82       0  102.0      2  Bangalore        No
# 72   83       0  101.0      1    Kolkata        No
# 53   83       1   98.0      1      Delhi       Yes
# 31   83       1  103.0      1    Kolkata        No
# 5    84       0    NaN      1  Bangalore       Yes
#
# [100 rows x 6 columns]

# %%
df = df.dropna()

# %%
df['fever'] = df['fever'].astype(int)
# Out:
# <ipython-input-35-ae876dcae292>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fever'] = df['fever'].astype(int)

# %%
df['age']=df['age'].add(2)
df
# Out:
#     age  gender  fever  cough       city has_covid
# 0    64       1  103.0      1    Kolkata        No
# 1    31       1  100.0      1      Delhi       Yes
# 2    46       1  101.0      1      Delhi        No
# 3    35       0   98.0      1    Kolkata        No
# 4    69       0  101.0      1     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   16       0  104.0      1  Bangalore        No
# 96   55       0  101.0      2    Kolkata       Yes
# 97   24       0  101.0      1  Bangalore        No
# 98    9       0   98.0      2     Mumbai        No
# 99   14       0   98.0      2    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.count
# Out:
# <bound method DataFrame.count of     age  gender  fever  cough       city has_covid
# 0    64       1  103.0      1    Kolkata        No
# 1    31       1  100.0      1      Delhi       Yes
# 2    46       1  101.0      1      Delhi        No
# 3    35       0   98.0      1    Kolkata        No
# 4    69       0  101.0      1     Mumbai        No
# ..  ...     ...    ...    ...        ...       ...
# 95   16       0  104.0      1  Bangalore        No
# 96   55       0  101.0      2    Kolkata       Yes
# 97   24       0  101.0      1  Bangalore        No
# 98    9       0   98.0      2     Mumbai        No
# 99   14       0   98.0      2    Kolkata       Yes
#
# [100 rows x 6 columns]>

# %%
s=df['fever'].median()
s
# Out:
# 101.0

# %%
s=df['fever'].mean()
s
# Out:
# 100.84444444444445

# %%
g=df.filter(items=['city','has_covid'])
g
# Out:
#          city has_covid
# 0     Kolkata        No
# 1       Delhi       Yes
# 2       Delhi        No
# 3     Kolkata        No
# 4      Mumbai        No
# ..        ...       ...
# 95  Bangalore        No
# 96    Kolkata       Yes
# 97  Bangalore        No
# 98     Mumbai        No
# 99    Kolkata       Yes
#
# [100 rows x 2 columns]

# %%
p=df.rename(columns={'has_covid':'covid_positive'})
p
# Out:
#     age  gender  fever  cough       city covid_positive
# 0    64       1  103.0      1    Kolkata             No
# 1    31       1  100.0      1      Delhi            Yes
# 2    46       1  101.0      1      Delhi             No
# 3    35       0   98.0      1    Kolkata             No
# 4    69       0  101.0      1     Mumbai             No
# ..  ...     ...    ...    ...        ...            ...
# 95   16       0  104.0      1  Bangalore             No
# 96   55       0  101.0      2    Kolkata            Yes
# 97   24       0  101.0      1  Bangalore             No
# 98    9       0   98.0      2     Mumbai             No
# 99   14       0   98.0      2    Kolkata            Yes
#
# [100 rows x 6 columns]

# %%
df['new_case']=df['fever'].where(df['fever']>100,other=0)
df
# Out:
#     age  gender  fever  cough       city has_covid  new_case
# 0    64       1  103.0      1    Kolkata        No     103.0
# 1    31       1  100.0      1      Delhi       Yes       0.0
# 2    46       1  101.0      1      Delhi        No     101.0
# 3    35       0   98.0      1    Kolkata        No       0.0
# 4    69       0  101.0      1     Mumbai        No     101.0
# ..  ...     ...    ...    ...        ...       ...       ...
# 95   16       0  104.0      1  Bangalore        No     104.0
# 96   55       0  101.0      2    Kolkata       Yes     101.0
# 97   24       0  101.0      1  Bangalore        No     101.0
# 98    9       0   98.0      2     Mumbai        No       0.0
# 99   14       0   98.0      2    Kolkata       Yes       0.0
#
# [100 rows x 7 columns]
