# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat459/python/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#q.1
#pandas is python library used for data analysis.it is used with heterogenous data and it used to make dataframes and series.

# %%
#q.2
#series is an one dimensional array
#dataframe is a two dimensional array

# %%
import pandas as pd

# %%
data={'A':[1,2,3,4,5],'B':[6,7,8,9,10],}
df=pd.DataFrame(data)
print(df)
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
# index is used for easy data retrieval and we can access any data from the index value

# %%
#5
df["new_column"]=[1,2,3,4,5]
df
# Out:
#    A   B  new_column
# 0  1   6           1
# 1  2   7           2
# 2  3   8           3
# 3  4   9           4
# 4  5  10           5

# %%
df = df.drop('A', axis=1)
df
# Out:
#     B
# 0   6
# 1   7
# 2   8
# 3   9
# 4  10

# %%
# for cheak any missing value
df.isnull().sum()
# Out:
# B    0
# dtype: int64

# %%
# for drop the missing values
df.dropna()
# for missing value
df.fillna(0)

# %%
#loc[]: Label-based indexing.
# iloc[]: Index position-based.

# %%
# for remove duplicates
df.drop_duplicates()
# Out:
#     B
# 0   6
# 1   7
# 2   8
# 3   9
# 4  10

# %%
# cheak datatype
df.dtypes
# Out:
# B    int64
# dtype: object

# %%
df.describe()
# Out:
#                B
# count   5.000000
# mean    8.000000
# std     1.581139
# min     6.000000
# 25%     7.000000
# 50%     8.000000
# 75%     9.000000
# max    10.000000

# %%
# ans of 18 and 20
df['B'].nunique()
# Out:
# 5

# %%
df.sort_index()
df.sort_values(by='B')
# Out:
#     B
# 0   6
# 1   7
# 2   8
# 3   9
# 4  10

# %%
# PIVOT  table IS USED FOR CREATE A TABLE WITH USUNG aggregate funtion
