# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("//content//apple_sales_2024.csv")

# %%
df.head(3)
# Out:
#        State         Region  iPhone Sales (in million units)  \
# 0  Chongqing  Greater China                             7.46
# 1    Germany         Europe                             8.63
# 2         UK         Europe                             5.61
#
#    iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                           6.75                          1.19
# 1                          14.06                          7.03
# 2                          14.09                          8.78
#
#    Wearables (in million units)  Services Revenue (in billion $)
# 0                          5.88                            15.88
# 1                          7.42                            10.12
# 2                          8.19                            19.85

# %%
df.tail(3)
# Out:
#         State         Region  iPhone Sales (in million units)  \
# 997   Germany         Europe                            25.47
# 998  Shenzhen  Greater China                            15.34
# 999  Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 997                           7.69                          7.90
# 998                           8.81                          8.24
# 999                           4.06                          3.41
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 997                          6.90                            15.00
# 998                          8.78                            15.49
# 999                          5.69                            14.29

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          State         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                             7.46
# 1      Germany         Europe                             8.63
# 2           UK         Europe                             5.61
# 3     Shanghai  Greater China                             7.82
# 4     Thailand   Rest of Asia                            16.70
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                            29.86
# 996      Texas  North America                            27.83
# 997    Germany         Europe                            25.47
# 998   Shenzhen  Greater China                            15.34
# 999   Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                             6.75                          1.19
# ...

# %%
df.sample(5)
# Out:
#          State         Region  iPhone Sales (in million units)  \
# 595  Chongqing  Greater China                            14.27
# 799      Spain         Europe                            26.90
# 497    Beijing  Greater China                            12.71
# 692    Germany         Europe                             5.21
# 877   Thailand   Rest of Asia                             7.62
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 595                           5.51                          6.30
# 799                          13.22                          3.30
# 497                           6.18                          4.33
# 692                          10.41                          4.26
# 877                           2.90                          8.03
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 595                          2.92                             9.17
# ...

# %%
df2 = df.iloc[:4 , :3]
df2
# Out:
#        State         Region  iPhone Sales (in million units)
# 0  Chongqing  Greater China                             7.46
# 1    Germany         Europe                             8.63
# 2         UK         Europe                             5.61
# 3   Shanghai  Greater China                             7.82

# %%
k = df.loc[1:3 , ['Region' , 'iPhone Sales (in million units)']]
k
# Out:
#           Region  iPhone Sales (in million units)
# 1         Europe                             8.63
# 2         Europe                             5.61
# 3  Greater China                             7.82

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=1000, step=1),
#  Index(['State', 'Region', 'iPhone Sales (in million units)',
#         'iPad Sales (in million units)', 'Mac Sales (in million units)',
#         'Wearables (in million units)', 'Services Revenue (in billion $)'],
#        dtype='object')]

# %%
a = df.empty
a
# Out:
# False

# %%
df.isnull().sum()
# Out:
# State                              0
# Region                             0
# iPhone Sales (in million units)    0
# iPad Sales (in million units)      0
# Mac Sales (in million units)       0
# Wearables (in million units)       0
# Services Revenue (in billion $)    0
# dtype: int64

# %%
 df.dropna()
# Out:
#          State         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                             7.46
# 1      Germany         Europe                             8.63
# 2           UK         Europe                             5.61
# 3     Shanghai  Greater China                             7.82
# 4     Thailand   Rest of Asia                            16.70
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                            29.86
# 996      Texas  North America                            27.83
# 997    Germany         Europe                            25.47
# 998   Shenzhen  Greater China                            15.34
# 999   Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                             6.75                          1.19
# 1                            14.06                          7.03
# ...

# %%
t = df.ndim
t
# Out:
# 2

# %%
i = df.shape
i
# Out:
# (1000, 7)

# %%
r = df.size
r
# Out:
# 7000

# %%
b = df.values
b
# Out:
# array([['Chongqing', 'Greater China', 7.46, ..., 1.19, 5.88, 15.88],
#        ['Germany', 'Europe', 8.63, ..., 7.03, 7.42, 10.12],
#        ['UK', 'Europe', 5.61, ..., 8.78, 8.19, 19.85],
#        ...,
#        ['Germany', 'Europe', 25.47, ..., 7.9, 6.9, 15.0],
#        ['Shenzhen', 'Greater China', 15.34, ..., 8.24, 8.78, 15.49],
#        ['Shanghai', 'Greater China', 26.3, ..., 3.41, 5.69, 14.29]],
#       dtype=object)

# %%
v = df.groupby('Region')['Mac Sales (in million units)'].sum()
v
# Out:
# Region
# Europe           1111.22
# Greater China    1212.80
# North America    1028.96
# Rest of Asia      982.94
# Rest of World    1219.84
# Name: Mac Sales (in million units), dtype: float64

# %%
v = df.groupby('Region')['Mac Sales (in million units)'].mean()
v
# Out:
# Region
# Europe           5.447157
# Greater China    5.537900
# North America    5.780674
# Rest of Asia     5.522135
# Rest of World    5.519638
# Name: Mac Sales (in million units), dtype: float64

# %%
c = df.groupby('Region')['iPhone Sales (in million units)'].sum()
c
# Out:
# Region
# Europe           3563.12
# Greater China    3868.28
# North America    3124.14
# Rest of Asia     3091.50
# Rest of World    3797.46
# Name: iPhone Sales (in million units), dtype: float64

# %%
c = df.groupby('Region')['iPhone Sales (in million units)'].mean()
c
# Out:
# Region
# Europe           17.466275
# Greater China    17.663379
# North America    17.551348
# Rest of Asia     17.367978
# Rest of World    17.183077
# Name: iPhone Sales (in million units), dtype: float64

# %%
d = df.groupby('Region')['iPad Sales (in million units)'].sum()
d
# Out:
# Region
# Europe           1745.66
# Greater China    1862.95
# North America    1625.44
# Rest of Asia     1473.26
# Rest of World    1858.57
# Name: iPad Sales (in million units), dtype: float64

# %%
d = df.groupby('Region')['iPad Sales (in million units)'].mean()
d
# Out:
# Region
# Europe           8.557157
# Greater China    8.506621
# North America    9.131685
# Rest of Asia     8.276742
# Rest of World    8.409819
# Name: iPad Sales (in million units), dtype: float64

# %%
e = df.groupby('State')['Services Revenue (in billion $)'].sum()
e
# Out:
# State
# Australia       541.19
# Beijing         532.03
# Brazil          523.41
# California      591.67
# Canada          550.15
# Chongqing       535.93
# Florida         324.07
# France          550.11
# Germany         419.05
# Hong Kong       631.51
# Illinois        468.27
# India           414.79
# Indonesia       458.83
# Italy           450.80
# Japan           518.63
# Mexico          486.78
# New York        471.09
# Shanghai        548.40
# Shenzhen        532.85
# South Africa    600.22
# South Korea     464.21
# Spain           427.29
# Texas           426.11
# Thailand        410.69
# UK              569.05
# Name: Services Revenue (in billion $), dtype: float64

# %%
e = df.groupby('State')['Services Revenue (in billion $)'].mean()
e
# Out:
# State
# Australia       12.585814
# Beijing         12.372791
# Brazil          11.378478
# California      12.588723
# Canada          11.959783
# Chongqing       13.398250
# Florida         12.464231
# France          12.793256
# Germany         11.325676
# Hong Kong       12.630200
# Illinois        13.379143
# India           12.569394
# Indonesia       12.074474
# Italy           11.863158
# Japan           12.965750
# Mexico          12.481538
# New York        12.732162
# Shanghai        12.753488
# Shenzhen        12.391860
# South Africa    12.770638
# South Korea     13.653235
# Spain           10.956154
# Texas           12.912424
# Thailand        12.445152
# UK              12.107447
# Name: Services Revenue (in billion $), dtype: float64

# %%
f = e = df.groupby('Region')['Wearables (in million units)'].sum()
f
# Out:
# Region
# Europe           1353.12
# Greater China    1514.86
# North America    1272.92
# Rest of Asia     1296.29
# Rest of World    1498.31
# Name: Wearables (in million units), dtype: float64

# %%
f = e = df.groupby('Region')['Wearables (in million units)'].mean()
f
# Out:
# Region
# Europe           6.632941
# Greater China    6.917169
# North America    7.151236
# Rest of Asia     7.282528
# Rest of World    6.779683
# Name: Wearables (in million units), dtype: float64

# %%
h = df.min()
h
# Out:
# State                              Australia
# Region                                Europe
# iPhone Sales (in million units)         5.03
# iPad Sales (in million units)           2.02
# Mac Sales (in million units)            1.01
# Wearables (in million units)             2.0
# Services Revenue (in billion $)         5.01
# dtype: object

# %%
j = df.to_dict()

# %%
df.head(3)
# Out:
#        State         Region  iPhone Sales (in million units)  \
# 0  Chongqing  Greater China                             7.46
# 1    Germany         Europe                             8.63
# 2         UK         Europe                             5.61
#
#    iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                           6.75                          1.19
# 1                          14.06                          7.03
# 2                          14.09                          8.78
#
#    Wearables (in million units)  Services Revenue (in billion $)
# 0                          5.88                            15.88
# 1                          7.42                            10.12
# 2                          8.19                            19.85

# %%
p = df.columns.tolist()
p
# Out:
# ['State',
#  'Region',
#  'iPhone Sales (in million units)',
#  'iPad Sales (in million units)',
#  'Mac Sales (in million units)',
#  'Wearables (in million units)',
#  'Services Revenue (in billion $)']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x=df['Region'])
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
df['Region'].value_counts()
# Out:
# Region
# Rest of World    221
# Greater China    219
# Europe           204
# Rest of Asia     178
# North America    178
# Name: count, dtype: int64

# %%
df['Region'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
df['Region'].value_counts().plot(kind='pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df["State"].value_counts().plot(kind='pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(x=df['iPhone Sales (in million units)'])
plt.show()

# %%
sns.boxplot(x=df['Region'])
# Out:
# <Axes: xlabel='Region'>

# %%
plt.figure(figsize=(8, 8))

iphone_sales_distribution = df.groupby("Region")["iPhone Sales (in million units)"].sum()

iphone_sales_distribution.plot(kind="pie", autopct="%.2f")

plt.title("iPhone Sales Distribution by Region")

plt.ylabel("")

plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x="Region", y="iPhone Sales (in million units)", data=df)
plt.title("Distribution of IPHONE Sales by Region")
plt.ylabel("iPhone Sales (in million units)")
plt.xlabel("Region")
plt.show()

# %%
df2 = df
p = pd.crosstab(df['Region'], df['State'])
print(p)
# Out:
# State          Australia  Beijing  Brazil  California  Canada  Chongqing  \
# Region
# Europe                 0        0       0           0       0          0
# Greater China          0       43       0           0       0         40
# North America          0        0       0          47       0          0
# Rest of Asia           0        0       0           0       0          0
# Rest of World         43        0      46           0      46          0
#
# State          Florida  France  Germany  Hong Kong  ...  Mexico  New York  \
# Region                                              ...
# Europe               0      43       37          0  ...       0         0
# Greater China        0       0        0         50  ...       0         0
# North America       26       0        0          0  ...       0        37
# Rest of Asia         0       0        0          0  ...       0         0
# Rest of World        0       0        0          0  ...      39         0
#
# ...

# %%
sns.heatmap(p)
# Out:
# <Axes: xlabel='State', ylabel='Region'>
