# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat459/python/blob/main/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/covid_toy.csv")
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy="mean")

# %%
df['fever'] = si.fit_transform(df[['fever']])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df.shape
# Out:
# (100, 6)

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df2 =df.copy()

# %%
df2.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df2['gender'] = df2['gender'].map({"Male":1 , "Female":0})

# %%
df2.sample(3)
# Out:
#     age  gender  fever cough     city has_covid
# 30   15    Male  101.0  Mild    Delhi       Yes
# 1    27    Male  100.0  Mild    Delhi       Yes
# 77    8  Female  101.0  Mild  Kolkata        No

# %%
df2['gender'] = df2['gender'].map({'Male':1 , "Female":0})
df2['cough'] = df2['cough'].map({'Mild':0 , "strong":1})
df2['has_covid']=df2['has_covid'].map({'Yes':1 , 'No':0})
df2['city']=df2['city'].map({'Kolkata':0 , 'Bangalore':1,'Delhi':2,'Mumbai':3})

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df2.head(3)
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60     NaN  103.0    0.0     0          0
# 1   27     NaN  100.0    0.0     2          1
# 2   42     NaN  101.0    0.0     2          0

# %%
x = df2.drop(columns = ['has_covid'])  ## input data
y = df2['has_covid']  ## target data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2 , random_state = 34)

# %%
np.round(x_train.describe(),1)
# Out:
#         age  gender  fever  cough  city
# count  80.0     0.0   80.0   50.0  80.0
# mean   44.1     NaN  100.7    0.0   1.2
# std    24.8     NaN    1.9    0.0   1.0
# min     5.0     NaN   98.0    0.0   0.0
# 25%    20.0     NaN   99.0    0.0   0.0
# 50%    44.0     NaN  100.8    0.0   1.0
# 75%    65.2     NaN  102.0    0.0   2.0
# max    84.0     NaN  104.0    0.0   3.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
x_train_sc = sc.fit_transform(x_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
x_train_new = pd.DataFrame(x_train_sc , columns = x_train.columns)

# %%
np.round(x_train_new.describe(),1)
# Out:
#         age  gender  fever  cough  city
# count  80.0     0.0   80.0   50.0  80.0
# mean    0.0     NaN    0.0    0.0  -0.0
# std     1.0     NaN    1.0    0.0   1.0
# min    -1.6     NaN   -1.5    0.0  -1.2
# 25%    -1.0     NaN   -0.9    0.0  -1.2
# 50%    -0.0     NaN    0.1    0.0  -0.2
# 75%     0.9     NaN    0.7    0.0   0.7
# max     1.6     NaN    1.8    0.0   1.7

# %%
np.round(x_train.describe(),1)
# Out:
#         age  gender  fever  cough  city
# count  80.0     0.0   80.0   50.0  80.0
# mean   44.1     NaN  100.7    0.0   1.2
# std    24.8     NaN    1.9    0.0   1.0
# min     5.0     NaN   98.0    0.0   0.0
# 25%    20.0     NaN   99.0    0.0   0.0
# 50%    44.0     NaN  100.8    0.0   1.0
# 75%    65.2     NaN  102.0    0.0   2.0
# max    84.0     NaN  104.0    0.0   3.0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn = MinMaxScaler()

# %%
x_train_mn = mn.fit_transform(x_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py:769: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmin(X, axis=axis))
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py:786: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmax(X, axis=axis))

# %%
x_train_new = pd.DataFrame(x_train_mn ,columns = x_train.columns)

# %%
np.round(x_train_new.describe(),2)
# Out:
#          age  gender  fever  cough   city
# count  80.00     0.0  80.00   50.0  80.00
# mean    0.49     NaN   0.45    0.0   0.41
# std     0.31     NaN   0.31    0.0   0.35
# min     0.00     NaN   0.00    0.0   0.00
# 25%     0.19     NaN   0.17    0.0   0.00
# 50%     0.49     NaN   0.47    0.0   0.33
# 75%     0.76     NaN   0.67    0.0   0.67
# max     1.00     NaN   1.00    0.0   1.00
