# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat459/python/blob/main/Meesho_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.meesho.com/tshirts-men/pl/3k8?Category[0][id]=5195&Category[0][label]=Men%20T-shirts&Category[0][payload]=eyJmaWVsZCI6ImxhYmVscy4xIiwib3AiOiJpbiIsInZhbHVlIjoiNTE5NSJ9&Gender[0][id]=444&Gender[0][label]=Men&Gender[0][payload]=eyJmaWVsZCI6ImxhYmVscy45Iiwib3AiOiJpbiIsInZhbHVlIjoiNDQ0In0%3D"

page = requests.get(url)
print(page)
soup = BeautifulSoup(page.text, 'html')
print(soup)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# ...

# %%
table = soup.find_all("div",class_='NewProductCardstyled__ProductHeaderWrapper-sc-6y2tys-32')

print(table)
# Out:
# [<div class="NewProductCardstyled__ProductHeaderWrapper-sc-6y2tys-32 knWeEt"><p class="sc-eDvSVe gQDOBc NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU" color="greyT2" font-size="16px" font-weight="book">Comfy Designer Men Tshirts</p></div>, <div class="NewProductCardstyled__ProductHeaderWrapper-sc-6y2tys-32 knWeEt"><p class="sc-eDvSVe gQDOBc NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU" color="greyT2" font-size="16px" font-weight="book">Urbane Designer Men Tshirts</p></div>, <div class="NewProductCardstyled__ProductHeaderWrapper-sc-6y2tys-32 knWeEt"><p class="sc-eDvSVe gQDOBc NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU NewProductCardstyled__StyledDesktopProductTitle-sc-6y2tys-5 ejhQZU" color="greyT2" font-size="16px" font-weight="book">Fancy Designer Men Tshirts</p></div>, <div class="New
# ...

# %%
name = []
for i in table:
  names = i.text
  name.append(names)
print(name)
print(len(name))
# Out:
# ['Comfy Designer Men Tshirts', 'Urbane Designer Men Tshirts', 'Fancy Designer Men Tshirts', 'Classy Glamorous Men Tshirts', 'Classy Partywear Men Tshirts', 'Trendy Glamorous Men Tshirts', 'Fancy Retro Men Tshirts', 'Pretty Designer Men Tshirts', 'Trendy Elegant Men Tshirts', 'Fancy Retro Men Tshirts', "KASPY Men's Tshirts", 'Cotton Men Cotton Regular Tshirts', 'Trendy Fabulous Men Tshirts', 'Fancy Glamorous Men Tshirts', 'Urbane Graceful Men Tshirts', 'Cotton Blend Men Cotton Blend Regular Tshirts', 'Classic Latest Men Tshirts', 'Classic Fabulous Men Tshirts', 'Polyester Men Polyester Regular Tshirts', "Eyebogler Men's Tshirts"]
# 20

# %%
p = soup.find_all("h5", class_ = "sc-eDvSVe dwCrSh")
price=[]
for i in p:
  prices = i.text
  price.append(prices)
print(price)
print(len(price))
# Out:
# ['₹331 ', '₹177', '₹129 ', '₹148 ', '₹119 ', '₹208 ', '₹188 ', '₹327 ', '₹225 ', '₹460 ', '₹194 ', '₹160 ', '₹294 ', '₹281 ', '₹230 ', '₹273 ', '₹198 ', '₹271 ', '₹259 ', '₹300 ']
# 20

# %%
k = soup.find_all("span", class_="sc-eDvSVe laVOtN")
rating=[]
for i in k:
  ratings = i.text
  rating.append(ratings)
print(rating)
print(len(rating))
# Out:
# ['3.9', '3.8', '3.9', '3.8', '3.8', '4.0', '3.9', '4.0', '3.7', '4.0', '3.8', '3.7', '4.0', '3.7', '3.8', '3.8', '3.9', '3.7', '3.9']
# 19

# %%
l = soup.find_all('span', class_="sc-eDvSVe XndEO NewProductCardstyled__RatingCount-sc-6y2tys-22 iaGtYc NewProductCardstyled__RatingCount-sc-6y2tys-22 iaGtYc")
review=[]
for i in l:
  reviews=i.text
  review.append(reviews)
print(review)
print(len(review))
# Out:
# ['5887 Reviews', '13420 Reviews', '13139 Reviews', '13402 Reviews', '3525 Reviews', '245 Reviews', '24688 Reviews', '16727 Reviews', '16363 Reviews', '1463 Reviews', '8660 Reviews', '5801 Reviews', '5390 Reviews', '3314 Reviews', '27654 Reviews', '574 Reviews', '2558 Reviews', '421 Reviews', '449 Reviews']
# 19

# %%
import numpy as np
import pandas as pd

# Find the maximum length among all lists
max_len = max(len(name), len(price), len(rating), len(review))

# Define a function to pad a list with None until it reaches max_len
def pad_list(lst, length, pad_value=None):
    return lst + [pad_value] * (length - len(lst))

name = pad_list(name, max_len)
price = pad_list(price, max_len)
rating = pad_list(rating, max_len)
review = pad_list(review, max_len)

df = pd.DataFrame({
    'Product Name': name,
    'Price': price,
    'Rating': rating,
    'Review': review
})
print(df)
# Out:
#                                      Product Name  Price Rating         Review
# 0                      Comfy Designer Men Tshirts  ₹331     3.9   5887 Reviews
# 1                     Urbane Designer Men Tshirts   ₹177    3.8  13420 Reviews
# 2                      Fancy Designer Men Tshirts  ₹129     3.9  13139 Reviews
# 3                    Classy Glamorous Men Tshirts  ₹148     3.8  13402 Reviews
# 4                    Classy Partywear Men Tshirts  ₹119     3.8   3525 Reviews
# 5                    Trendy Glamorous Men Tshirts  ₹208     4.0    245 Reviews
# 6                         Fancy Retro Men Tshirts  ₹188     3.9  24688 Reviews
# 7                     Pretty Designer Men Tshirts  ₹327     4.0  16727 Reviews
# 8                      Trendy Elegant Men Tshirts  ₹225     3.7  16363 Reviews
# 9                         Fancy Retro Men Tshirts  ₹460     4.0   1463 Reviews
# 10                            KASPY Men's Tshirts  ₹194     3.8   8660 Reviews
# ...

# %%
df = pd.DataFrame({
    'Product Name':name,
    'Price':price,
    'Rating':rating,
    'Review':review
})
print(df)
# Out:
#                                      Product Name  Price Rating         Review
# 0                      Comfy Designer Men Tshirts  ₹331     3.9   5887 Reviews
# 1                     Urbane Designer Men Tshirts   ₹177    3.8  13420 Reviews
# 2                      Fancy Designer Men Tshirts  ₹129     3.9  13139 Reviews
# 3                    Classy Glamorous Men Tshirts  ₹148     3.8  13402 Reviews
# 4                    Classy Partywear Men Tshirts  ₹119     3.8   3525 Reviews
# 5                    Trendy Glamorous Men Tshirts  ₹208     4.0    245 Reviews
# 6                         Fancy Retro Men Tshirts  ₹188     3.9  24688 Reviews
# 7                     Pretty Designer Men Tshirts  ₹327     4.0  16727 Reviews
# 8                      Trendy Elegant Men Tshirts  ₹225     3.7  16363 Reviews
# 9                         Fancy Retro Men Tshirts  ₹460     4.0   1463 Reviews
# 10                            KASPY Men's Tshirts  ₹194     3.8   8660 Reviews
# ...

# %%
df = df.drop(df.index[-1])  # Drops the last row

# %%
df["Price"] = df["Price"].str.replace("₹", "")

# %%
df["Review"] = df["Review"].str.replace(" Reviews", "")
df['Review']=df['Review'].astype(int)
df['Rating']=df['Rating'].astype(float)
df['Price']=df['Price'].astype(int)

# %%
df.to_csv("Messo_data.csv")

# %%
df.dtypes
# Out:
# Product Name     object
# Price             int64
# Rating          float64
# Review            int64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
plt.figure(figsize=(8, 5))
plt.bar(df['Product Name'], df['Rating'], color='skyblue')
plt.xlabel("Product Name", fontsize=12)
plt.ylabel("Rating", fontsize=12)
plt.title("Average Rating by Product Name", fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
avg_ratings = df.groupby('Product Name')['Price'].mean()
plt.figure(figsize=(8, 8))
plt.pie(avg_ratings, labels=avg_ratings.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title("Average Rating by Product Name")
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.bar(df['Product Name'], df['Review'], color='skyblue')
plt.xlabel("Product Name", fontsize=12)
plt.ylabel("Review", fontsize=12)
plt.title(" Review by Product Name", fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
Coments=['Good','Nice','Excellent','Cheap','Quality Poor','Not worth it','Not worth it', 'Average product','Not Good',
    'Better','Very Good','Bad Quality','Satisfied','Not Satisfied','Price is too High accoridng this product','Damaged','Good','Best','Okay']
sales_data = [
    14560047, 2573654, 5637894, 3637849, 4563748,
    6748576, 2225467, 3373657, 7365533, 5578364,
    66627654, 7787653, 8887543, 9998765, 1786352,
    1176547, 1297654, 1365434, 1408653,
]

# %%
df['Comments']=Coments
df['Sales']=sales_data

df.head()
# Out:
#                    Product Name  Price  Rating  Review      Comments     Sales
# 0    Comfy Designer Men Tshirts    331     3.9    5887          Good  14560047
# 1   Urbane Designer Men Tshirts    177     3.8   13420          Nice   2573654
# 2    Fancy Designer Men Tshirts    129     3.9   13139     Excellent   5637894
# 3  Classy Glamorous Men Tshirts    148     3.8   13402         Cheap   3637849
# 4  Classy Partywear Men Tshirts    119     3.8    3525  Quality Poor   4563748

# %%
from textblob import TextBlob

# %%
def textblob_sentiment_analysis(Comments):
    # Get the sentiment polarity of the review
    sentiment = TextBlob(Comments).sentiment.polarity

    # Classify based on the polarity score
    if sentiment > 0.1:
        return 'positive'
    elif sentiment < -0.1:
        return 'negative'
    else:
        return 'neutral'

# %%
df['sentiment']=df['Comments'].apply(textblob_sentiment_analysis)

# %%
df.head()
# Out:
#                    Product Name  Price  Rating  Review      Comments  \
# 0    Comfy Designer Men Tshirts    331     3.9    5887          Good
# 1   Urbane Designer Men Tshirts    177     3.8   13420          Nice
# 2    Fancy Designer Men Tshirts    129     3.9   13139     Excellent
# 3  Classy Glamorous Men Tshirts    148     3.8   13402         Cheap
# 4  Classy Partywear Men Tshirts    119     3.8    3525  Quality Poor
#
#       Sales sentiment
# 0  14560047  positive
# 1   2573654  positive
# 2   5637894  positive
# 3   3637849  positive
# 4   4563748  negative

# %%
sentiment_distribution=df['sentiment'].value_counts()
sentiment_distribution
# Out:
# sentiment
# positive    11
# negative     7
# neutral      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9, 5))
sns.barplot(x=sentiment_distribution.index, y=sentiment_distribution.values)
plt.title("Distribution of Sentiment")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x="Rating", hue="sentiment", data=df)
plt.title("Sentiment Distribution by Rating")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.legend(title="sentiment")
plt.show()

# %%
df.columns
# Out:
# Index(['Product Name', 'Price', 'Rating', 'Review', 'Comments', 'Sales',
#        'sentiment'],
#       dtype='object')

# %% [markdown]
# # Machine--learning

# %%
df.isnull().sum()
# Out:
# Product Name    0
# Price           0
# Rating          0
# Review          0
# Comments        0
# Sales           0
# sentiment       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['Product Name', 'Price', 'Rating', 'Review', 'Comments', 'Sales',
#        'sentiment'],
#       dtype='object')

# %%
# Splitting Data
X = df.drop(columns=['Sales'])
y = df['Sales']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
#
numeric = ['Price', 'Rating', 'Review', 'Comments']
categorial = ['Product Name']

# %%
df.head()
# Out:
#                    Product Name  Price  Rating  Review      Comments  \
# 0    Comfy Designer Men Tshirts    331     3.9    5887          Good
# 1   Urbane Designer Men Tshirts    177     3.8   13420          Nice
# 2    Fancy Designer Men Tshirts    129     3.9   13139     Excellent
# 3  Classy Glamorous Men Tshirts    148     3.8   13402         Cheap
# 4  Classy Partywear Men Tshirts    119     3.8    3525  Quality Poor
#
#       Sales sentiment
# 0  14560047  positive
# 1   2573654  positive
# 2   5637894  positive
# 3   3637849  positive
# 4   4563748  negative

# %%
scaler = StandardScaler()
encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

X_train_num = scaler.fit_transform(X_train[numeric])
X_test_num = scaler.transform(X_test[numeric])

X_train_cat = encoder.fit_transform(y_train[categorial])
X_test_cat = encoder.transform(y_test[categorial])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-60f1fd96fc9c> in <cell line: 0>()
#       2 encoder = OneHotEncoder(handle_unknown='ignore', sparse_output=False)
#       3
# ----> 4 X_train_num = scaler.fit_transform(X_train[numeric])
#       5 X_test_num = scaler.transform(X_test[numeric])
#       6
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
# ...
