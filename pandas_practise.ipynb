# %% [markdown]
# <a href="https://colab.research.google.com/github/rajat459/python/blob/main/pandas_practise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Employee_data_50.csv")
df
# Out:
#     Unnamed: 0  EmployeeID           Name Department JoiningDate  Age  Salary  \
# 0            0         101    Nina Walker    Finance  2018-09-10   36   87065
# 1            1         102   Rachel Lewis         HR  2019-08-09   47  142093
# 2            2         103      Bob Smith         IT  2012-05-10   44  149299
# 3            3         104  Charlie Brown         HR  2013-07-18   49   82606
# 4            4         105    Paul Turner         HR  2013-02-04   27   61534
# 5            5         106      Ian Clark    Finance  2012-12-31   29  144663
# 6            6         107      David Lee         HR  2018-06-20   43   90397
# 7            7         108  Alice Johnson         HR  2014-06-27   31  141387
# 8            8         109      David Lee    Finance  2015-12-10   45   51016
# 9            9         110  Alice Johnson         HR  2011-04-12   33  139789
# 10          10         111    Nina Walker         HR  2013-05-23   31  105591
# ...

# %%
# question1
filtered = df[(df['Age'] > 30) & (df['Salary'] > 30)]
filtered
# Out:
#     Unnamed: 0  EmployeeID           Name Department JoiningDate  Age  Salary  \
# 0            0         101    Nina Walker    Finance  2018-09-10   36   87065
# 1            1         102   Rachel Lewis         HR  2019-08-09   47  142093
# 2            2         103      Bob Smith         IT  2012-05-10   44  149299
# 3            3         104  Charlie Brown         HR  2013-07-18   49   82606
# 6            6         107      David Lee         HR  2018-06-20   43   90397
# 7            7         108  Alice Johnson         HR  2014-06-27   31  141387
# 8            8         109      David Lee    Finance  2015-12-10   45   51016
# 9            9         110  Alice Johnson         HR  2011-04-12   33  139789
# 10          10         111    Nina Walker         HR  2013-05-23   31  105591
# 11          11         112    Paul Turner         HR  2010-11-27   42  139812
# 13          13         114    Helen Scott         IT  2015-11-06   49   74300
# ...

# %%
#question 2
avg_salary = df.groupby('Department')['Salary'].mean()
avg_salary
# Out:
# Department
# Finance       96712.000000
# HR           103489.277778
# IT            95108.500000
# Marketing     84577.666667
# Sales         88390.125000
# Name: Salary, dtype: float64

# %%
#3
df['agegroup'] = np.where(df['Age'] < 30, 'Young',
np.where(df['Age'] < 40, 'Mid', 'Senior'))
df['agegroup']
# Out:
# 0        Mid
# 1     Senior
# 2     Senior
# 3     Senior
# 4      Young
# 5      Young
# 6     Senior
# 7        Mid
# 8     Senior
# 9        Mid
# 10       Mid
# 11    Senior
# 12     Young
# 13    Senior
# 14    Senior
# 15       Mid
# 16    Senior
# 17    Senior
# 18       Mid
# 19    Senior
# 20    Senior
# 21     Young
# 22    Senior
# 23    Senior
# 24       Mid
# 25    Senior
# 26       Mid
# 27       Mid
# 28    Senior
# 29       Mid
# 30       Mid
# 31     Young
# 32       Mid
# 33    Senior
# 34     Young
# 35    Senior
# 36       Mid
# 37     Young
# 38     Young
# 39    Senior
# 40       Mid
# 41    Senior
# 42       Mid
# 43     Young
# 44    Senior
# 45    Senior
# 46    Senior
# 47    Senior
# 48       Mid
# 49     Young
# Name: agegroup, dtype: object

# %%
#question 4
top_performers = df.loc[df.groupby('Department')['Rating'].idxmax()]
top_performers
# Out:
#     Unnamed: 0  EmployeeID           Name Department JoiningDate  Age  Salary  \
# 44          44         145  Quincy Foster    Finance  2014-12-12   46  102251
# 3            3         104  Charlie Brown         HR  2013-07-18   49   82606
# 25          25         126      Sam Baker         IT  2016-08-30   52  111228
# 27          27         128      Bob Smith  Marketing  2012-08-13   36   90774
# 42          42         143      Ian Clark      Sales  2017-07-10   34   76854
#
#     Experience       Location  Rating  ProjectsCompleted
# 44          14         Boston     4.3                 12
# 3            7  San Francisco     4.6                 23
# 25           9        Chicago     5.0                 20
# 27           6       New York     4.9                  9
# 42           7         Boston     4.9                  8

# %%
# question 5
total_projects = df[df['Department'] == 'IT']['ProjectsCompleted'].sum()
total_projects
# Out:
# 152

# %%
#question6
df['year'] = pd.to_datetime('today').year - pd.to_datetime(df['JoiningDate']).dt.year
df['year']
# Out:
# 0      6
# 1      5
# 2     12
# 3     11
# 4     11
# 5     12
# 6      6
# 7     10
# 8      9
# 9     13
# 10    11
# 11    14
# 12    10
# 13     9
# 14     5
# 15     6
# 16     7
# 17    14
# 18    10
# 19     5
# 20    12
# 21     8
# 22    10
# 23     5
# 24     7
# 25     8
# 26    11
# 27    12
# 28     8
# 29    11
# 30    13
# 31     5
# 32    14
# 33     8
# 34    12
# 35     7
# 36     5
# 37    13
# 38    12
# 39     7
# 40     9
# 41     5
# 42     7
# 43    12
# 44    10
# 45    14
# 46     6
# 47     7
# 48     6
# 49    13
# Name: year, dtype: int32

# %%
top_earners = df.sort_values(by='Salary', ascending=False)
top_earners.head(5)
# Out:
#     Unnamed: 0  EmployeeID           Name Department JoiningDate  Age  Salary  \
# 2            2         103      Bob Smith         IT  2012-05-10   44  149299
# 5            5         106      Ian Clark    Finance  2012-12-31   29  144663
# 1            1         102   Rachel Lewis         HR  2019-08-09   47  142093
# 7            7         108  Alice Johnson         HR  2014-06-27   31  141387
# 11          11         112    Paul Turner         HR  2010-11-27   42  139812
#
#     Experience       Location  Rating  ProjectsCompleted  year
# 2           10         Boston     2.4                  7    12
# 5           14  San Francisco     3.6                 11    12
# 1            9  San Francisco     1.5                 23     5
# 7            8  San Francisco     2.4                 13    10
# 11           5        Chicago     2.9                 22    14

# %%
#8
df['JoiningDate'] = pd.to_datetime(df['JoiningDate'])
employees = df[df['JoiningDate'].dt.year < 2015]
employees
# Out:
#     Unnamed: 0  EmployeeID           Name Department JoiningDate  Age  Salary  \
# 2            2         103      Bob Smith         IT  2012-05-10   44  149299
# 3            3         104  Charlie Brown         HR  2013-07-18   49   82606
# 4            4         105    Paul Turner         HR  2013-02-04   27   61534
# 5            5         106      Ian Clark    Finance  2012-12-31   29  144663
# 7            7         108  Alice Johnson         HR  2014-06-27   31  141387
# 9            9         110  Alice Johnson         HR  2011-04-12   33  139789
# 10          10         111    Nina Walker         HR  2013-05-23   31  105591
# 11          11         112    Paul Turner         HR  2010-11-27   42  139812
# 12          12         113     Tina Scott         IT  2014-01-22   28   73247
# 17          17         118  Alice Johnson         HR  2010-05-11   50  136807
# 18          18         119    Paul Turner         HR  2014-08-13   33   62185
# ...

# %%
#9
avg_rating = df.groupby('Location')['Rating'].mean()
avg_rating
# Out:
# Location
# Boston           3.100000
# Chicago          2.760000
# Los Angeles      2.440000
# New York         2.812500
# San Francisco    2.691667
# Name: Rating, dtype: float64

# %%
#10
df['Ratings']=[df['Rating'] < 3.0, Rating=3.0]
# Out:
#   File "<ipython-input-47-40ac09ae6fb1>", line 2
#     df['Ratings']=[df['Rating'] < 3.0, Rating=3.0]
#                                        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
#11
total_salary = df['Salary'].sum()
total_salary
# Out:
# 4802175

# %%
#12
employee_count = df['Department'].value_counts()
employee_count
# Out:
# Department
# HR           18
# IT           10
# Finance       8
# Sales         8
# Marketing     6
# Name: count, dtype: int64

# %%
#13
experience = df[df['Experience'] > 5]
experience
# Out:
#     Unnamed: 0  EmployeeID           Name Department JoiningDate  Age  Salary  \
# 0            0         101    Nina Walker    Finance  2018-09-10   36   87065
# 1            1         102   Rachel Lewis         HR  2019-08-09   47  142093
# 2            2         103      Bob Smith         IT  2012-05-10   44  149299
# 3            3         104  Charlie Brown         HR  2013-07-18   49   82606
# 5            5         106      Ian Clark    Finance  2012-12-31   29  144663
# 6            6         107      David Lee         HR  2018-06-20   43   90397
# 7            7         108  Alice Johnson         HR  2014-06-27   31  141387
# 8            8         109      David Lee    Finance  2015-12-10   45   51016
# 12          12         113     Tina Scott         IT  2014-01-22   28   73247
# 15          15         116  Charlie Brown    Finance  2018-09-07   38  132798
# 16          16         117  Quincy Foster  Marketing  2017-12-29   42   59268
# ...

# %%
#14
pivot_table = df.pivot_table(values='Salary',
                             index='Department',
                             columns='Location',
                             aggfunc='sum')
pivot_table
# Out:
# Location      Boston   Chicago  Los Angeles  New York  San Francisco
# Department
# Finance     295466.0  113704.0          NaN       NaN       364526.0
# HR          541954.0  416408.0     153063.0  101214.0       650168.0
# IT          229834.0  111228.0     280471.0  329552.0            NaN
# Marketing        NaN  171126.0          NaN   90774.0       245566.0
# Sales       282461.0  253808.0          NaN  170852.0            NaN

# %%
#15

correlation = df[['Age', 'Salary', 'Rating']].corr()
correlation
# Out:
#              Age    Salary    Rating
# Age     1.000000 -0.090518  0.011507
# Salary -0.090518  1.000000 -0.104710
# Rating  0.011507 -0.104710  1.000000

# %%
#16

high = df[(df['ProjectsCompleted'] > 15) & (df['Rating'] >= 4.0)]

high
# Out:
#     Unnamed: 0  EmployeeID           Name Department JoiningDate  Age  Salary  \
# 3            3         104  Charlie Brown         HR  2013-07-18   49   82606
# 25          25         126      Sam Baker         IT  2016-08-30   52  111228
# 40          40         141    Frank Green         HR  2015-08-10   30   88660
# 45          45         146    Nina Walker      Sales  2010-07-09   53   72662
# 49          49         150  Alice Johnson      Sales  2011-07-17   26  102256
#
#     Experience       Location  Rating  ProjectsCompleted  year
# 3            7  San Francisco     4.6                 23    11
# 25           9        Chicago     5.0                 20     8
# 40          12         Boston     4.2                 21     9
# 45          14       New York     4.2                 24    14
# 49          13        Chicago     4.4                 22    13

# %%
#17

df = df.drop_duplicates(subset='EmployeeID')
df
# Out:
#     Unnamed: 0  EmployeeID           Name Department JoiningDate  Age  Salary  \
# 0            0         101    Nina Walker    Finance  2018-09-10   36   87065
# 1            1         102   Rachel Lewis         HR  2019-08-09   47  142093
# 2            2         103      Bob Smith         IT  2012-05-10   44  149299
# 3            3         104  Charlie Brown         HR  2013-07-18   49   82606
# 4            4         105    Paul Turner         HR  2013-02-04   27   61534
# 5            5         106      Ian Clark    Finance  2012-12-31   29  144663
# 6            6         107      David Lee         HR  2018-06-20   43   90397
# 7            7         108  Alice Johnson         HR  2014-06-27   31  141387
# 8            8         109      David Lee    Finance  2015-12-10   45   51016
# 9            9         110  Alice Johnson         HR  2011-04-12   33  139789
# 10          10         111    Nina Walker         HR  2013-05-23   31  105591
# ...

# %%
#18
median_salary = df.groupby('Age')['Salary'].median()
median_salary
# Out:
# Age
# 26    102256.0
# 27     57114.5
# 28     93876.0
# 29    144663.0
# 30     88660.0
# 31    105591.0
# 32     97875.5
# 33    100987.0
# 34     76854.0
# 36     90774.0
# 38    115494.0
# 39    109388.5
# 41     55258.0
# 42     74386.0
# 43     90397.0
# 44    103935.0
# 45     93897.5
# 46     77906.0
# 47    142093.0
# 49     78453.0
# 50    113704.0
# 52    111228.0
# 53     62615.0
# 54     62666.0
# Name: Salary, dtype: float64

# %%
#19

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# EmployeeID           0
# Name                 0
# Department           0
# JoiningDate          0
# Age                  0
# Salary               0
# Experience           0
# Location             0
# Rating               0
# ProjectsCompleted    0
# year                 0
# dtype: int64

# %%
#20
df['Salary'] = df['Salary'].fillna(df.groupby('Department')['Salary'].median())
df['Salary']
# Out:
# 0      87065
# 1     142093
# 2     149299
# 3      82606
# 4      61534
# 5     144663
# 6      90397
# 7     141387
# 8      51016
# 9     139789
# 10    105591
# 11    139812
# 12     73247
# 13     74300
# 14    124065
# 15    132798
# 16     59268
# 17    136807
# 18     62185
# 19    113704
# 20    136779
# 21     89099
# 22     58571
# 23     88044
# 24    101214
# 25    111228
# 26     98984
# 27     90774
# 28     52568
# 29    112592
# 30    117563
# 31     52695
# 32     98190
# 33     55258
# 34    137538
# 35     89504
# 36     83159
# 37     63986
# 38    111858
# 39     62666
# 40     88660
# 41     53561
# 42     76854
# 43    114505
# 44    102251
# 45     72662
# 46     58392
# 47     80535
# 48    128603
# 49    102256
# Name: Salary, dtype: int64
